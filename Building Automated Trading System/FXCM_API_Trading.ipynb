# %% [markdown]
# ### FXCM API Trading

# %%
# install fxcm library
# !pip install fxcmpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fxcmpy in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: python-engineio==4.3.1 in /usr/local/lib/python3.7/dist-packages (from fxcmpy) (4.3.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from fxcmpy) (1.3.5)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.7/dist-packages (from fxcmpy) (1.4.1)
# Requirement already satisfied: configparser in /usr/local/lib/python3.7/dist-packages (from fxcmpy) (5.3.0)
# Requirement already satisfied: python-socketio==5.0.4 in /usr/local/lib/python3.7/dist-packages (from fxcmpy) (5.0.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from fxcmpy) (2.23.0)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from python-socketio==5.0.4->fxcmpy) (0.22.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fxcmpy) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fxcmpy) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fxcmpy) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->fxcmpy) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->fxcmpy) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->fxcmpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->fxcmpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->fxcmpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->fxcmpy) (1.7.1)

# %%
# import necessary libraries
import fxcmpy
import time

# %%
# Initializing API connections and defining trade parameters
token = "5ee2b28aab020abfd63ddbfe0d2ec451c7e4e0f2"
con = fxcmpy.fxcmpy(access_token = token, log_level = 'error', server='demo')
pair = 'EUR/USD'

# Get historical data
data = con.get_candles(pair, period='m5', number=250)
"""periods can be m1, m5, m15 and m30, H1, H2, H3, H4, H6 and H8, D1, W1, M1"""

# Streaming data
"""for streaming data, we first need to subscribe to a currency pair"""
con.subscribe_market_data('EUR/USD')
starttime
con.get_last_price('EUR/USD')
con.get_prices('EUR/USD')
con.unsubscribe_market_data('EUR/USD')

data
# Out:
# WARNING:FXCM:Default account set to 4406946, to change use set_default_account().
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2022-09-23 00:10:00  0.98372   0.98361  0.98381  0.98356  0.98386   0.98376
# 2022-09-23 00:15:00  0.98361   0.98327  0.98380  0.98326  0.98375   0.98340
# 2022-09-23 00:20:00  0.98325   0.98344  0.98349  0.98320  0.98339   0.98357
# 2022-09-23 00:25:00  0.98345   0.98340  0.98358  0.98330  0.98357   0.98354
# 2022-09-23 00:30:00  0.98341   0.98358  0.98362  0.98341  0.98355   0.98370
# ...                      ...       ...      ...      ...      ...       ...
# 2022-09-23 20:35:00  0.96907   0.96942  0.96951  0.96902  0.96924   0.96961
# 2022-09-23 20:40:00  0.96941   0.96950  0.96954  0.96939  0.96961   0.96966
# 2022-09-23 20:45:00  0.96951   0.96916  0.96957  0.96900  0.96967   0.96935
# 2022-09-23 20:50:00  0.96915   0.96877  0.96919  0.96870  0.96935   0.96905
# 2022-09-23 20:55:00  0.96875   0.96863  0.96899  0.96828  0.96903   0.96956
#
#                      askhigh   asklow  tickqty
# date
# 2022-09-23 00:10:00  0.98396  0.98370      528
# 2022-09-23 00:15:00  0.98393  0.98339      636
# 2022-09-23 00:20:00  0.98363  0.98334      679
# 2022-09-23 00:25:00  0.98370  0.98344      388
# 2022-09-23 00:30:00  0.98376  0.98355      488
# ...                      ...      ...      ...
# 2022-09-23 20:35:00  0.96971  0.96920      338
# 2022-09-23 20:40:00  0.96970  0.96957      224
# 2022-09-23 20:45:00  0.96973  0.96919      285
# 2022-09-23 20:50:00  0.96937  0.96892      619
# 2022-09-23 20:55:00  0.96980  0.96895      500
#
# [250 rows x 9 columns]

# %%
# Trading account data
con.get_accounts().T

con.get_open_positions().T
# Out:
#                                     0                 1                 2  \
# t                                   1                 1                 1
# ratePrecision                       5                 5                 5
# tradeId                     259560475         259560476         259560477
# accountName                  04406946          04406946          04406946
# accountId                     4406946           4406946           4406946
# roll                                0                 0                 0
# com                                 0                 0                 0
# open                          0.96956           1.35917           1.35873
# valueDate
# grossPL                          -9.3          -3.23832          -6.47454
# close                         0.96863           1.35873           1.35917
# visiblePL                        -9.3              -4.4              -4.4
# isDisabled                      False             False             False
# currency                      EUR/USD           USD/CAD           USD/CAD
# isBuy                            True              True             False
# amountK                            10                10                20
# currencyPoint                     1.0           0.73586           1.47172
# time                   09242022065651    09242022065651    09242022065652
# usedMargin                       27.5              25.0              50.0
# orderId                     882193336         882193337         882193338
# OpenOrderRequestTXT              None              None              None
# OpenOrderReqID       Request-22770586  Request-22770588  Request-22770592
# TradeIDOrigin                    None              None              None
# child_trailingStop               none              none              none
# child_trailing                     -1                -1                -1
# stop                                0                 0                 0
# stopMove                            0                 0                 0
# limit                               0                 0                 0
#
#                                     3                 4                 5  \
# t                                   1                 1                 1
# ratePrecision                       5                 5                 5
# tradeId                     259560478         259560578         259560579
# accountName                  04406946          04406946          04406946
# accountId                     4406946           4406946           4406946
# roll                                0                 0                 0
# com                                 0                 0                 0
# open                          0.96863           0.96956           1.35917
# valueDate
# grossPL                          -9.3              -9.3          -3.23832
# close                         0.96956           0.96863           1.35873
# visiblePL                        -9.3              -9.3              -4.4
# isDisabled                      False             False             False
# currency                      EUR/USD           EUR/USD           USD/CAD
# isBuy                           False              True              True
# amountK                            10                10                10
# currencyPoint                     1.0               1.0           0.73586
# time                   09242022065654    09242022082339    09242022082340
# usedMargin                       27.5              27.5              25.0
# orderId                     882193339         882193592         882193593
# OpenOrderRequestTXT              None              None              None
# OpenOrderReqID       Request-22770594  Request-22785593  Request-22785596
# TradeIDOrigin                    None              None              None
# child_trailingStop               none              none              none
# child_trailing                     -1                -1                -1
# stop                                0                 0                 0
# stopMove                            0                 0                 0
# limit                               0                 0                 0
#
#                                     6                 7
# t                                   1                 1
# ratePrecision                       5                 5
# tradeId                     259560580         259560581
# accountName                  04406946          04406946
# accountId                     4406946           4406946
# roll                                0                 0
# com                                 0                 0
# open                          1.35873           0.96863
# valueDate
# grossPL                      -6.47454              -9.3
# close                         1.35917           0.96956
# visiblePL                        -4.4              -9.3
# isDisabled                      False             False
# currency                      USD/CAD           EUR/USD
# isBuy                           False             False
# amountK                            20                10
# currencyPoint                 1.47172               1.0
# time                   09242022082341    09242022082342
# usedMargin                       50.0              27.5
# orderId                     882193594         882193595
# OpenOrderRequestTXT              None              None
# OpenOrderReqID       Request-22785597  Request-22785598
# TradeIDOrigin                    None              None
# child_trailingStop               none              none
# child_trailing                     -1                -1
# stop                                0                 0
# stopMove                            0                 0
# limit                               0                 0

# %%
con.get_open_positions_summary().T
con.get_closed_positions()
con.get_orders()

# %%
# Orders
con.create_market_buy_order('EUR/USD', 10)
con.create_market_buy_order('USD/CAD', 10)
con.create_market_sell_order('USD/CAD', 20)
con.create_market_sell_order('EUR/USD', 10)

order = con.open_trade(symbol="USD/CAD", is_buy = False, is_in_pips = True, amount=10, time_in_force = 'GTC', stop=.9, trailing_step = True,
                       order_type = 'AtMarket', limit=9)

con.close_trade(trade_id = tradeId, amount=1000)
con.close_all_for_symbol('USD/CAD')

# closing connection
con.close()
# Out:
# WARNING:FXCM:Got a delete event for orders: {'t': 3, 'orderId': '882193592', 'action': 'D'}.
# WARNING:FXCM:Got a insert event for open positions: {'t': 1, 'ratePrecision': 5, 'tradeId': '259560578', 'accountName': '04406946', 'accountId': '4406946', 'roll': 0, 'com': 0, 'open': 0.96956, 'valueDate': '', 'grossPL': -9.3, 'close': 0.96863, 'visiblePL': -9.3, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': True, 'amountK': 10, 'currencyPoint': 1, 'time': '09242022082339', 'usedMargin': 27.5, 'orderId': '882193592', 'OpenOrderRequestTXT': None, 'OpenOrderReqID': 'Request-22785593', 'TradeIDOrigin': None, 'child_trailingStop': 'none', 'child_trailing': -1, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/usr/local/lib/python3.7/dist-packages/fxcmpy/fxcmpy.py", line 2715, in __on_open_pos_update__
#     pos = self.open_pos[trade_id]
# KeyError: 259560578
#
# WARNING:FXCM:Got a delete event for orders: {'t': 3, 'orderId': '882193593', 'action': 'D'}.
# WARNING:FXCM:Got a insert event for open positions: {'t': 1, 'ratePrecision': 5, 'tradeId': '259560579', 'accountName': '04406946', 'accountId': '4406946', 'roll': 0, 'com': 0, 'open': 1.35917, 'valueDate': '', 'grossPL': -3.23832, 'close': 1.35873, 'visiblePL': -4.4, 'isDisabled': False, 'currency': 'USD/CAD', 'isBuy': True, 'amountK': 10, 'currencyPoint': 0.73586, 'time': '09242022082340', 'usedMargin': 25, 'orderId': '882193593', 'OpenOrderRequestTXT': None, 'OpenOrderReqID': 'Request-22785596', 'TradeIDOrigin': None, 'child_trailingStop': 'none', 'child_trailing': -1, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/usr/local/lib/python3.7/dist-packages/fxcmpy/fxcmpy.py", line 2715, in __on_open_pos_update__
#     pos = self.open_pos[trade_id]
# KeyError: 259560579
#
# WARNING:FXCM:Got a delete event for orders: {'t': 3, 'orderId': '882193594', 'action': 'D'}.
# WARNING:FXCM:Got a insert event for open positions: {'t': 1, 'ratePrecision': 5, 'tradeId': '259560580', 'accountName': '04406946', 'accountId': '4406946', 'roll': 0, 'com': 0, 'open': 1.35873, 'valueDate': '', 'grossPL': -6.47454, 'close': 1.35917, 'visiblePL': -4.4, 'isDisabled': False, 'currency': 'USD/CAD', 'isBuy': False, 'amountK': 20, 'currencyPoint': 1.47172, 'time': '09242022082341', 'usedMargin': 50, 'orderId': '882193594', 'OpenOrderRequestTXT': None, 'OpenOrderReqID': 'Request-22785597', 'TradeIDOrigin': None, 'child_trailingStop': 'none', 'child_trailing': -1, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/usr/local/lib/python3.7/dist-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/usr/local/lib/python3.7/dist-packages/fxcmpy/fxcmpy.py", line 2715, in __on_open_pos_update__
#     pos = self.open_pos[trade_id]
# KeyError: 259560580
#
# WARNING:FXCM:Got a delete event for orders: {'t': 3, 'orderId': '882193595', 'action': 'D'}.
# WARNING:FXCM:Got a insert event for open positions: {'t': 1, 'ratePrecision': 5, 'tradeId': '259560581', 'accountName': '04406946', 'accountId': '4406946', 'roll': 0, 'com': 0, 'open': 0.96863, 'valueDate': '', 'grossPL': -9.3, 'close': 0.96956, 'visiblePL': -9.3, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 10, 'currencyPoint': 1, 'time': '09242022082342', 'usedMargin': 27.5, 'orderId': '882193595', 'OpenOrderRequestTXT': None, 'OpenOrderReqID': 'Request-22785598', 'TradeIDOrigin': None, 'child_trailingStop': 'none', 'child_trailing': -1, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# ERROR:FXCM:Server reports an error: {'executed': False, 'error': 'Incorrect value of parameter <trailing_step> is <1>.   Valid values are 0.1 for dynamic or integer values within (10,300) '}.
# ERROR:FXCM:URL: https://api-demo.fxcm.com:443/trading/open_trade
# ERROR:FXCM:Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer e1awJlInVd6CwkUqBdXX5ee2b28aab020abfd63ddbfe0d2ec451c7e4e0f2', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '170'}
# ERROR:FXCM:Params: {'account_id': 4406946, 'symbol': 'USD/CAD', 'is_buy': 'false', 'rate': 0.0, 'amount': 10, 'at_market': 0.0, 'order_type': 'AtMarket', 'time_in_force': 'GTC', 'limit': 9.0, 'is_in_pips': 'true', 'stop': 0.9, 'trailing_step': 1}
# ERROR:FXCM:Bearer token: Bearer e1awJlInVd6CwkUqBdXX5ee2b28aab020abfd63ddbfe0d2ec451c7e4e0f2
# ERROR:FXCM:Connection status: established
# ERROR:FXCM:Socket session id: e1awJlInVd6CwkUqBdXX
# ERROR:FXCM:Can not parse server answer to json object: {"response":{"executed":false,"error":"Incorrect value of parameter <trailing_step> is <1>.   Valid values are 0.1 for dynamic or integer values within (10,300) "}}.
# WARNING:FXCM:Missing orderId in servers answer.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-587f144bc1a3> in <module>
#       8                        order_type = 'AtMarket', limit=9)
#       9
# ---> 10 con.close_trade(trade_id = tradeId, amount=1000)
#      11 con.close_all_for_symbol('USD/CAD')
#      12
#
# NameError: name 'tradeId' is not defined
